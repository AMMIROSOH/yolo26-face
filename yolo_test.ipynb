# %%
from ultralytics import YOLO

# %%
model26 = YOLO("D:/Datasets/yolo26/wider/runs/pose/face/final_run/weights/best.pt")
model8 = YOLO("yolov8n-face.onnx")
# Out:
# WARNING Unable to automatically guess model task, assuming 'task=detect'. Explicitly define task for your model, i.e. 'task=detect', 'segment', 'classify','pose' or 'obb'.

# %%
# r26 = model26.predict("C:/Users/PARATCO/Desktop/video2.mp4", save=True, project="tests", name="video_test_26")
r8 = model8.predict("C:/Users/PARATCO/Desktop/video2.mp4", save=True, project="tests", name="video_test_8", )
# Out:
# Loading yolov8n-face.onnx for ONNX Runtime inference...
# requirements: Ultralytics requirements ['onnx', 'onnxruntime-gpu'] not found, attempting AutoUpdate...
# ...
#    ---------------------------------------- 0.0/16.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/16.4 MB ? eta -:--:--
#    - -------------------------------------- 0.8/16.4 MB 4.2 MB/s eta 0:00:04
#    --- ------------------------------------ 1.6/16.4 MB 4.4 MB/s eta 0:00:04
#    ------ --------------------------------- 2.6/16.4 MB 4.3 MB/s eta 0:00:04
#    --------- ------------------------------ 3.9/16.4 MB 4.8 MB/s eta 0:00:03
#    --------- ------------------------------ 3.9/16.4 MB 4.8 MB/s eta 0:00:03
#    --------- ------------------------------ 3.9/16.4 MB 4.8 MB/s eta 0:00:03
#    --------------- ------------------------ 6.3/16.4 MB 4.3 MB/s eta 0:00:03
#    --------------- ------------------------ 6.6/16.4 MB 4.0 MB/s eta 0:00:03
# ...
